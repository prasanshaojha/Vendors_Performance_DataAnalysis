# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
import os 
import pandas as pd
from logger import logging 
from timelog import timetaken
from connect_database import database_connect

# %%
conn = database_connect()

# %%
#finding tables present in our inventory database 

query = 'select name from sys.tables'

tables = pd.read_sql_query(query,conn)
tables
# Out:
#               name
# 0  begin_inventory
# 1    end_inventory
# 2  purchase_prices
# 3            sales
# 4         purchase
# 5   vendor_invoice
# 6        purchases

# %%
#getting preview of the tables in my database 
rows = 5
for t in tables['name']:
    query = f'select top ({rows})* from [{t}]'
    table_data = pd.read_sql_query(query,conn)
    logging.info(f'\n preview of tables {t}')
    logging.info(table_data)
    display(table_data)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand      Price   startDate
# 0  750mL       8  12.990000  2024-01-01
# 1  750mL       7  10.990000  2024-01-01
# 2  750mL       6  36.990002  2024-01-01
# 3  750mL       3  38.990002  2024-01-01
# 4  750mL       6  34.990002  2024-01-01
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# ...
