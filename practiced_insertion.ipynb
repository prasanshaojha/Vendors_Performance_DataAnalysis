# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
server = r'DESKTOP-2QO4EC0\SQLEXPRESS'
database = 'inventory'

connection_string = f"mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
engine = create_engine(connection_string, fast_executemany= True)

# %%
filelist = r'C:\Users\ojhap\Documents\PRACTICE\InventoryDataAnalysis\datasets'

for file in os.listdir(filelist):
    print(file)

#df = pd.read_csv(csv_file)
# Out:
# .ipynb_checkpoints
# begin_inventory.csv
# end_inventory.csv
# purchases.csv
# purchase_prices.csv
# sales.csv
# Untitled.ipynb
# vendor_invoice.csv

# %%
csv_file = r'C:\Users\ojhap\Documents\PRACTICE\InventoryDataAnalysis\datasets\sales.csv'
df = pd.read_csv(csv_file)
df.head(10)
# Out:
#             InventoryId  Store  Brand                  Description  \
# 0   1_HARDERSFIELD_1004      1   1004   Jim Beam w/2 Rocks Glasses
# 1   1_HARDERSFIELD_1004      1   1004   Jim Beam w/2 Rocks Glasses
# 2   1_HARDERSFIELD_1004      1   1004   Jim Beam w/2 Rocks Glasses
# 3   1_HARDERSFIELD_1004      1   1004   Jim Beam w/2 Rocks Glasses
# 4   1_HARDERSFIELD_1005      1   1005      Maker's Mark Combo Pack
# 5   1_HARDERSFIELD_1005      1   1005      Maker's Mark Combo Pack
# 6   1_HARDERSFIELD_1005      1   1005      Maker's Mark Combo Pack
# 7   1_HARDERSFIELD_1005      1   1005      Maker's Mark Combo Pack
# 8  1_HARDERSFIELD_10058      1  10058  F Coppola Dmd Ivry Cab Svgn
# 9  1_HARDERSFIELD_10058      1  10058  F Coppola Dmd Ivry Cab Svgn
#
#          Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0       750mL              1         16.49       16.49  2024-01-01   750.0
# 1       750mL              2         32.98       16.49  2024-01-02   750.0
# ...

# %%
chunksize = 50000

for chunk in pd.read_csv(csv_file, chunksize = chunksize):
    chunk.to_sql('sales',engine, if_exists = 'append', index = False)
    print(f"inserted {len(chunk)} rows")
# Out:
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# inserted 50000 rows
# ...

# %%
purchase_file = r'C:\Users\ojhap\Documents\PRACTICE\InventoryDataAnalysis\datasets\purchases.csv'

chunksize = 100000
for chunk in pd.read_csv(purchase_file, chunksize = chunksize):
    chunk.to_sql('purchase', engine, if_exists = 'append', index = False)
    print (f"inserted {len(chunk)} rows")
# Out:
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 100000 rows
# inserted 72474 rows

# %%
purchase_file = r'C:\Users\ojhap\Documents\PRACTICE\InventoryDataAnalysis\datasets\vendor_invoice.csv'

chunksize = 100000
for chunk in pd.read_csv(purchase_file, chunksize = chunksize):
    chunk.to_sql('vendor_invoice', engine, if_exists = 'append', index = False)
    print (f"inserted {len(chunk)} rows")
# Out:
# inserted 5543 rows
